# %%
import pandas as pd

df= pd.read_csv ('./datasets/attacks.csv', encoding='unicode_escape')
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
## isolate fatal attacks and dropna 

df.columns
FSsub= df[['Fatal (Y/N)', 'Species ', 'Country']].dropna()
fatalattacks= FSsub[FSsub['Fatal (Y/N)']== 'Y']
fatalattacks
list(fatalattacks['Species '])
# Out:
# ['Tiger shark',
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'Tiger shark',
#  'White shark',
#  '3+ m shark',
#  'White shark',
#  'Tiger shark, 2.5 m',
#  'White shark, 3.9 to 4.2 m',
#  'Bull shark, 3.5 m',
#  'Bull shark',
#  'Mako shark',
#  'Tiger shark, 3.5 m',
#  '3.5 to 4 m shark',
#  'White shark, 4 to 5 m',
#  'Tiger shark',
#  "7' shark",
#  '3 m to 4 m white shark',
#  '2 m shark',
#  'Tiger shark, 3m ',
#  'Thought to involve a white shark',
#  'White shark',
#  'Tiger shark?',
#  'Bull shark',
#  'Tiger shark, 4.8 m',
#  'White shark, 4m',
#  'Tiger shark',
#  '2.5 m shark',
#  "White shark, 15' to 16' ",
#  'White shark, 5m',
#  'White shark, 4 m to 5m ',
#  'White shark, 4m ',
#  'Thought to involve a bull shark',
#  "White shark, 10'",
#  'White shark',
#  "White shark, >6'",
#  "Bull shark, 6'",
#  'Zambesi shark',
#  ' Tiger shark, 2.8m',
#  'White shark x 2',
#  'Oceanic whitetip shark, 2.5m ',
# ...

# %%
## Get list of species 

fatalattacks['Species ']
fatalattacks['fatals']= fatalattacks['Species '].str.extract(r'(\w{3,}\sshark)|(?:\w{3,}\spointer)')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
fatalattacks['Species '].replace('Blue pointer', 'blue pointer shark', inplace= True)
fatalattacks['Species '].replace('Blue pointers', 'blue pointer shark', inplace= True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
fatalattacks[fatalattacks['Species ']== 'whaler shark']
# Out:
# Empty DataFrame
# Columns: [Fatal (Y/N), Species , Country, fatals, Fatal_Species]
# Index: []

# %%
## Create correct dataframe

fatalattacks['Fatal_Species']= fatalattacks['Species '].str.extract(r'(\w{3,}?-\w{3,}\sshark|\w{3,}?\s\w{3,}\sshark|\w{3,}\sshark)')
fataldf= fatalattacks[['Fatal (Y/N)', 'Fatal_Species', 'Country']]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fataldf= fataldf.dropna()

fataldf.applymap(lambda x: x.title())
# Out:
#      Fatal (Y/N)       Fatal_Species     Country
# 6              Y         Tiger Shark      Brazil
# 58             Y         Tiger Shark  Costa Rica
# 59             Y          Blue Shark       Libya
# 64             Y         Tiger Shark        Cuba
# 155            Y         White Shark   Australia
# ...          ...                 ...         ...
# 6276           Y         Tiger Shark      Belize
# 6293           Y  Blue Pointer Shark   Australia
# 6294           Y  Blue Pointer Shark   Australia
# 6295           Y  Blue Pointer Shark   Australia
# 6296           Y    Grey Nurse Shark   Australia
#
# [307 rows x 3 columns]

# %%
## GET ALL ATTACKS BY SPECIES ##

# %%
spattacks= df[['Fatal (Y/N)', 'Species ']].dropna()
spattacks
spattacks['Species ']
spattacks['Species '].replace('Blue pointer', 'blue pointer shark', inplace= True)
spattacks['Species '].replace('Blue pointers', 'blue pointer shark', inplace= True)

spattacks['Species']= spattacks['Species '].str.extract(r'(\w{3,}?-\w{3,}\sshark|\w{3,}?\s\w{3,}\sshark|\w{3,}\sshark)')
spattacks= spattacks[['Fatal (Y/N)','Species']].dropna()
spattacks.applymap(lambda x: x.title())
# Out:
#      Fatal (Y/N)             Species
# 0              N         White Shark
# 4              N         Tiger Shark
# 6              Y         Tiger Shark
# 7              N         Lemon Shark
# 8              N          Bull Shark
# ...          ...                 ...
# 6276           Y         Tiger Shark
# 6293           Y  Blue Pointer Shark
# 6294           Y  Blue Pointer Shark
# 6295           Y  Blue Pointer Shark
# 6296           Y    Grey Nurse Shark
#
# [1981 rows x 2 columns]
